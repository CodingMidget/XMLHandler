# %%
import pandas as pd
import xml.etree.ElementTree as ET
import os

# %%
import xml.etree.ElementTree as ET
import pandas as pd

def extract_kill_info(file):
    # Load and parse the XML file
    tree = ET.parse(file)  # Adjust the path if your file is elsewhere
    root = tree.getroot()
    
    # Prepare list to collect extracted data
    data = []
    
    # Traverse each skill
    for skill in root.findall(".//imgdir[@name='skill']/imgdir"):
        skill_id = skill.attrib.get('name')  # Skill ID like 1100000
        for level in skill.findall("imgdir[@name='level']/imgdir"):
            level_id = level.attrib.get('name')  # Level like 1, 2, 3, etc.
            row = {
                'skill_id': skill_id,
                'level': level_id,
                'mobCount': None,
                'lt': None,
                'rb': None,
                'damage': None,
                'mpCon': None,
                'hpCon': None
            }
            # Extract relevant fields
            for child in level:
                tag_name = child.attrib['name']
                if child.tag == 'int' and tag_name in row:
                    row[tag_name] = child.attrib['value']
                elif child.tag == 'vector' and tag_name in ['lt', 'rb']:
                    coords = (child.attrib['x'], child.attrib['y'])
                    row[tag_name] = str(coords)
            data.append(row)
    
    # Convert to a pandas DataFrame
    df = pd.DataFrame(data)
    
    # Display or export as needed
    # print(df)
    df.to_excel(file[:-8] + ".xlsx", index=False)  # Optional: save to Excel
    print(f'Done for {file[:-8]}')

directory = os.fsencode(r"File path here")
    
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".xml"): 
        extract_kill_info(filename)
    else:
        continue
# Out:
#    skill_id level mobCount                 lt              rb damage mpCon  \
# 0   0001003     1     None               None            None   None  None
# 1   0001004     1     None               None            None   None  None
# 2   0001005     1     None   ('-400', '-300')  ('400', '300')   None    30
# 3   0000008     1     None               None            None   None  None
# 4   0001006     1     None               None            None   None  None
# 5   0001001     1     None               None            None   None     5
# 6   0001001     2     None               None            None   None    10
# 7   0001001     3     None               None            None   None    15
# 8   0001002     1     None               None            None   None     4
# 9   0001002     2     None               None            None   None     7
# 10  0001002     3     None               None            None   None    10
# 11  0001000     1     None               None            None   None     3
# 12  0001000     2     None               None            None   None     5
# 13  0001000     3     None               None            None   None     7
# 14  0001007     1     None               None            None   None  None
# 15  0001007     2     None               None            None   None  None
# 16  0001007     3     None               None            None   None  None
# 17  0001009     1       30  ('-1000', '-300')  ('1000', '15')   None  None
# 18  0001010     1     None               None            None   None  None
# 19  0001011     1     None               None            None   None  None
# 20  0000012     1     None               None            None   None  None
# 21  0000012     2     None               None            None   None  None
# 22  0000012     3     None               None            None   None  None
# 23  0000012     4     None               None            None   None  None
# 24  0000012     5     None               None            None   None  None
# 25  0000012     6     None               None            None   None  None
# 26  0000012     7     None               None            None   None  None
# 27  0000012     8     None               None            None   None  None
# 28  0000012     9     None               None            None   None  None
# 29  0000012    10     None               None            None   None  None
# 30  0000012    11     None               None            None   None  None
# 31  0000012    12     None               None            None   None  None
# 32  0000012    13     None               None            None   None  None
# 33  0000012    14     None               None            None   None  None
# 34  0000012    15     None               None            None   None  None
# 35  0000012    16     None               None            None   None  None
# 36  0000012    17     None               None            None   None  None
# 37  0000012    18     None               None            None   None  None
# 38  0000012    19     None               None            None   None  None
# 39  0000012    20     None               None            None   None  None
# 40  0001013     1     None               None            None   None    10
# 41  0001013     2     None               None            None   None    10
# 42  0001014     1     None               None            None   None    10
# 43  0001015     1     None               None            None   None  None
# 44  0001017     1     None               None            None   None    10
# 45  0001020     1       15  ('-1000', '-300')  ('1000', '15')   None  None
# 46  0009000     1     None               None            None   None  None
# 47  0009001     1     None               None            None   None  None
# 48  0009002     1     None               None            None   None  None
# 49  0001018     1     None               None            None   None    10
# 50  0001019     1     None               None            None   None    10
# 51  0001031     1     None               None            None   None    10
# 52  0000100     1     None               None            None   None  None
#
#    hpCon
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
# 20  None
# 21  None
# 22  None
# 23  None
# 24  None
# 25  None
# 26  None
# 27  None
# 28  None
# 29  None
# 30  None
# 31  None
# 32  None
# 33  None
# 34  None
# 35  None
# 36  None
# 37  None
# 38  None
# 39  None
# 40  None
# 41  None
# 42  None
# 43  None
# 44  None
# 45  None
# 46  None
# 47  None
# 48  None
# 49  None
# 50  None
# 51  None
# 52  None
# Done for 000
#    skill_id level mobCount    lt    rb damage mpCon hpCon
# 0   1000000     1     None  None  None   None  None  None
# 1   1000001     1     None  None  None   None  None  None
# 2   1000001     2     None  None  None   None  None  None
# 3   1000001     3     None  None  None   None  None  None
# 4   1000001     4     None  None  None   None  None  None
# ..      ...   ...      ...   ...   ...    ...   ...   ...
# 56  1001005    16       10  None  None    180    16    25
# 57  1001005    17       12  None  None    185    16    25
# 58  1001005    18       12  None  None    190    16    25
# 59  1001005    19       12  None  None    195    16    25
# 60  1001005    20       12  None  None    200    18    30
#
# [61 rows x 8 columns]
# Done for 100
#     skill_id level mobCount                 lt              rb damage mpCon  \
# 0   10001000     1     None               None            None   None     3
# 1   10001000     2     None               None            None   None     5
# 2   10001000     3     None               None            None   None     7
# 3   10001001     1     None               None            None   None     5
# 4   10001001     2     None               None            None   None    10
# 5   10001001     3     None               None            None   None    15
# 6   10001002     1     None               None            None   None     4
# 7   10001002     2     None               None            None   None     7
# 8   10001002     3     None               None            None   None    10
# 9   10001003     1     None               None            None   None  None
# 10  10001004     1     None               None            None   None  None
# 11  10001005     1     None   ('-400', '-300')  ('400', '300')   None    30
# 12  10001006     1     None               None            None   None  None
# 13  10001007     1     None               None            None   None  None
# 14  10001007     2     None               None            None   None  None
# 15  10001007     3     None               None            None   None  None
# 16  10001009     1       30  ('-1000', '-300')  ('1000', '15')   None  None
# 17  10001010     1     None               None            None   None  None
# 18  10001011     1     None               None            None   None  None
# 19  10000100     1     None               None            None   None  None
# 20  10000018     1     None               None            None   None  None
# 21  10001013     1     None               None            None   None    11
# 22  10001014     1     None               None            None   None    10
# 23  10001014     2     None               None            None   None    10
# 24  10001015     1     None               None            None   None    10
# 25  10001016     1     None               None            None   None     1
# 26  10001019     1     None               None            None   None    10
# 27  10001020     1       15  ('-1000', '-300')  ('1000', '15')   None  None
# 28  10009000     1     None               None            None   None  None
# 29  10009001     1     None               None            None   None  None
# 30  10009002     1     None               None            None   None  None
# 31  10001022     1     None               None            None   None    10
# 32  10001023     1     None               None            None   None    10
# 33  10001031     1     None               None            None   None    10
# 34  10000012     1     None               None            None   None  None
# 35  10000012     2     None               None            None   None  None
# 36  10000012     3     None               None            None   None  None
# 37  10000012     4     None               None            None   None  None
# 38  10000012     5     None               None            None   None  None
# 39  10000012     6     None               None            None   None  None
# 40  10000012     7     None               None            None   None  None
# 41  10000012     8     None               None            None   None  None
# 42  10000012     9     None               None            None   None  None
# 43  10000012    10     None               None            None   None  None
# 44  10000012    11     None               None            None   None  None
# 45  10000012    12     None               None            None   None  None
# 46  10000012    13     None               None            None   None  None
# 47  10000012    14     None               None            None   None  None
# 48  10000012    15     None               None            None   None  None
# 49  10000012    16     None               None            None   None  None
# 50  10000012    17     None               None            None   None  None
# 51  10000012    18     None               None            None   None  None
# 52  10000012    19     None               None            None   None  None
# 53  10000012    20     None               None            None   None  None
#
#    hpCon
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
# 20  None
# 21  None
# 22  None
# 23  None
# 24  None
# 25  None
# 26  None
# 27  None
# 28  None
# 29  None
# 30  None
# 31  None
# 32  None
# 33  None
# 34  None
# 35  None
# 36  None
# 37  None
# 38  None
# 39  None
# 40  None
# 41  None
# 42  None
# 43  None
# 44  None
# 45  None
# 46  None
# 47  None
# 48  None
# 49  None
# 50  None
# 51  None
# 52  None
# 53  None
# Done for 1000
